# %% [markdown]
# #### Notebook config

# %%
# %load ~/software/fullwavepy/fullwavepy/config/jupyter.py
from fullwavepy import * # Load modules imported in fullwavepy/__init__.py
# -----------------------------------------------------------------------------
# Set aliases of frequently used jupyter magic commands
# -----------------------------------------------------------------------------
# %alias_magic mi matplotlib -p inline
# %alias_magic mn matplotlib -p notebook
# -----------------------------------------------------------------------------
# Set matplotlib backend
# -----------------------------------------------------------------------------
# non-interactive plots displayed in a notebook cell
# %matplotlib inline
# interactive plots displayed in a notebook cell
# %matplotlib notebook (interactive version)
# -----------------------------------------------------------------------------
# Set matplotlib style
# ----------------------------------------------------------------------------
plt.style.reload_library()
# a combined style (right overwrites left wherever they overlap):
plt.style.use(['default', 'ggplot'])
# print(plt.style.available) 
# -----------------------------------------------------------------------------
# Configure logging
# -----------------------------------------------------------------------------
# Set up loggers, handlers and load the log_lvl function
from fullwavepy.config.logging import *
# -----------------------------------------------------------------------------
# Set level of log-messages
log_lvl(ERROR) 
# Other options in order of increasing importance and 
# decreasing verbosity:
# TRACE, DEBUG, INFO, WARNING, ERROR, CRITICAL
# or using integers: 0, 10, 20, 30, 40, 50, respectively
# -----------------------------------------------------------------------------
# Autocompleting
# -----------------------------------------------------------------------------
#  Not sure if it works
#%config IPCompleter.greedy=True 
# -----------------------------------------------------------------------------
# Automatically reload modules before execution
#%load_ext autoreload
#%autoreload 2
# Out:
# Created `%mi` as an alias for `%matplotlib inline`.
# Created `%mn` as an alias for `%matplotlib notebook`.

# %% [markdown]
# Suppress printing logs except warnings and errors:

# %%
lll(40)

# %% [markdown]
# Set the path for projects accessible by the computational cluster:

# %%
path_eph = '/home/kmc3817/rds_home/my_ephemeral/PROJECTS/ch08_Kolumbo_volcano'

# %% [markdown]
# Load the experiment's metadata:

# %%
xp = PROTEUS()

# %% [markdown]
# ##### Test the `fullwavepy.fwi` package

# %%
# !python3 -m unittest fullwavepy.fwi.test  -v

# %% [markdown]
# ## Pre-requisites

# %% [markdown]
# ### Model box

# %%
xp = PROTEUS()
b01 = xp.box['kol1']
box = b01.box
box
# Out:
# [8000.0, 25000.0, -3000.0, 15000.0, 0, 4000.0]

# %% [markdown]
# ### Numerical solver

# %%
exe = { 
    'fullwave':  '~/PhD/fullwave3D/rev690/bin/fullwave3D.exe',
    'segyprep':  '/home/kmc3817/light_PhD/fullwave3D/segyprep_v3.16/bin/segyprep_v3.16' }

# %% [markdown]
# ### Discretisation

# %% [markdown]
# 3000 time samples is more than enough to capture the arrivals at all offsets, even for 2-sec time-window

# %%
dt = 0.0025 # seconds
ns = 3000   # samples
dx = 50     # metres

# %% [markdown]
# ### Source wavelet

# %%
xp.wvl.plot(aspect='auto') # fixme labels
wvl = xp.wvl.arr.arr

# %% [markdown]
# ### Starting model

# %%
svp = xp.svp.arr.extract(b01.extent)
# svp.plot(0,0,0, unit='i') # fixme units, add bt

# %% [markdown]
# Subset of field data to simulate

# %%
# %%time 
data_path = '/home/kmc3817/heavy_PhD/DATA/Santorini_2015/seismic/OBS/segy_local_coords/'
obs_hy = DataSet(data_path, io='proteus_hy')
ds = obs_hy.extract(b01.xy, path='./', name='obs_hy_b01')
# Out:
#  mkdir: cannot create directory ‘.//obs_hy_b01’: File exists
#
# CPU times: user 28 ms, sys: 76 ms, total: 104 ms
# Wall time: 27.8 s

# %% [markdown]
# # Init

# %%
# init project 
path = path_eph
# path = './'
env = {'SLAVES_WAVEFIELDSVTR': -100} # take a wavefield snapshot every 100 time steps
kwargs = dict(path=path, exe=exe, box=box, dt=dt, ns=ns, dx=dx, env=env, cat=0)
s01 = ProjSyn('method_s01', **kwargs)

# %% [markdown]
# # Inp

# %% [markdown]
# Prepare input:

# %%
# %%time 
syn.i.tvp.prep(svp)
syn.i.rsg.prep(wvl)
syn.i.rse.prep(fnames=['../../%s' % i for i in ds.fnames])
syn.i.sp.prep(reciprocity=True, ztype='d')
# Out:
# Content of  .//method_s01//inp/method_s01-RawSeis.txt :
# ../.././/obs_hy_b01/MGL1521_S104_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_S109_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_S112_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_S124_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_S125_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_S137_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_S157_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_S158_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_S177_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_S178_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_W105_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_W110_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_W123_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_W138_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_W139_4_x8000_25000_y-3000_15000.sgy
# ../.././/obs_hy_b01/MGL1521_W176_4_x8000_25000_y-3000_15000.sgy
#
# Content of  .//method_s01//inp/method_s01-SegyPrep.key :
# FFID : yes
# addtodepth : 0
# debug : yes
# dtms : 2.5
# dx : 50.0
# fixedarray : yes
# geometry : segy
# io : sgy
# maxoffset : 1000000.0
# minoffset : 0
# nx1 : 341
# nx2 : 361
# nx3 : 81
# outseis : yes
# outsource : yes
# problem : synthetic
# reciprocity : True
# retain : yes
# text : yes
# ttime : 7500.0
# unique : yes
# xorigin : 8000.0
# xshift : 0
# yorigin : -3000.0
# yshift : 0
# ztype : d
#
# CPU times: user 5.15 s, sys: 3.04 s, total: 8.19 s
# Wall time: 22.7 s

# %% [markdown]
# Pre-process the input:

# %%
syn.i.sp.run()
syn.i.rnf.prep(b_abs=40, e_abs=50)
# Out:
#  SEGYPREP  -  Version 3.16.04
#  ********
#
#  Data preparation for 2D & 3D wavefield tomography
#
#  Project name set to method_s01
#  Preparing files for synthetics...
#
#  Grid points in-line:                    341
#  Grid points cross-line:                 361
#  Grid points vertically:                  81
#  Horiz grid spacing (metres):      50.0000000
#  Vert grid spacing (metres):       50.0000000
#  Model length (metres):            17000.0000
#  Model width (metres):             18000.0000
#  Model depth (metres):             4000.00000
#
#  Modelling time step (ms):         2.50000000
#  Output data delta-T (ms):         2.50000000
#  Output data length (ms):          7500.00000
#  Output data length (samples):          3000
#  Time steps to model:                   3000
#
#  Receiver-array fixed in space:          yes
#  Renumber original channel numbers:       no
#  Use FFID instead of SOURCE numbers:     yes
#  FFID numbers are unique:                yes
#  Renumber original FFID numbers:          no
#  Use composite shots:                     no
#  Apply source-receiver reciprocity:      yes
#
#  Reading multiple SEG-Y datafiles...
#  Reading: ../.././/obs_hy_b01/MGL1521_S104_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S109_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S112_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S124_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S125_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S137_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S157_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S158_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S177_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S178_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_W105_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_W110_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_W123_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_W138_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_W139_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_W176_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#
#  Total traces used:                        0
#  Reciprocal sources in model:              0
#  Reciprocal receivers in model:            0
#  Maximum receivers per source:             1
#
#  Reading source signatures...
#
#  Checking models...
#
#  Cannot open SGY file
#  Cannot open SGY file
#  Found model file method_s01-TrueVp.sgy
#  Vertical grid points in file:            81
#  Expecting:                               81
#  Profiles in file:                    123101
#  Expecting:                           123101
#  Maximum velocity (m/s):              6515.1
#  Minimum velocity (m/s):              1517.4
#  For high kernel:
#  Maximum allowable (m/s):            13187.0
#  High kernel OK below (Hz):              9.0
#  For low kernel:
#  Maximum allowable (m/s):             9900.0
#  Low kernel OK below (Hz):               4.9
#
#  There was nothing to plot
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-b502ec0489c8> in <module>
# ----> 1 syn.i.sp.run()
#       2 syn.i.rnf.prep(b_abs=40, e_abs=50)
#
# /usr/local/lib/python3.5/dist-packages/autologging.py in autologging_traced_instancemethod_delegator(self_, *args, **keywords)
#    1039             return proxy(method, args, keywords)
#    1040         else:
# -> 1041             return method(*args, **keywords)
#    1042
#    1043     autologging_traced_instancemethod_delegator._tracing_proxy = proxy
#
# ~/software/fullwavepy/fullwavepy/generic/decor.py in wrapper_timer(*args, **kwargs)
#      48
#      49     start_time = time.perf_counter()
# ---> 50     value = func(*args, **kwargs)
#      51     end_time = time.perf_counter()
#      52
#
# ~/software/fullwavepy/fullwavepy/project/files/text/runfiles.py in run(self, overwrite, **kwargs)
#     303
#     304     if raise_error:
# --> 305       raise ValueError(str(o) + errors_raised)
#     306
#     307   # -----------------------------------------------------------------------------
#
# ValueError:
#  SEGYPREP  -  Version 3.16.04
#  ********
#
#  Data preparation for 2D & 3D wavefield tomography
#
#  Project name set to method_s01
#  Preparing files for synthetics...
#
#  Grid points in-line:                    341
#  Grid points cross-line:                 361
#  Grid points vertically:                  81
#  Horiz grid spacing (metres):      50.0000000
#  Vert grid spacing (metres):       50.0000000
#  Model length (metres):            17000.0000
#  Model width (metres):             18000.0000
#  Model depth (metres):             4000.00000
#
#  Modelling time step (ms):         2.50000000
#  Output data delta-T (ms):         2.50000000
#  Output data length (ms):          7500.00000
#  Output data length (samples):          3000
#  Time steps to model:                   3000
#
#  Receiver-array fixed in space:          yes
#  Renumber original channel numbers:       no
#  Use FFID instead of SOURCE numbers:     yes
#  FFID numbers are unique:                yes
#  Renumber original FFID numbers:          no
#  Use composite shots:                     no
#  Apply source-receiver reciprocity:      yes
#
#  Reading multiple SEG-Y datafiles...
#  Reading: ../.././/obs_hy_b01/MGL1521_S104_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S109_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S112_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S124_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S125_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S137_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S157_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S158_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S177_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_S178_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_W105_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_W110_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_W123_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_W138_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_W139_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#  Reading: ../.././/obs_hy_b01/MGL1521_W176_4_x8000_25000_y-3000_15000.sgy
#  Unable to decode SEG-Y headers
#  Traces read from file:                    0
#
#  Total traces used:                        0
#  Reciprocal sources in model:              0
#  Reciprocal receivers in model:            0
#  Maximum receivers per source:             1
#
#  Reading source signatures...
#
#  Checking models...
#
#  Cannot open SGY file
#  Cannot open SGY file
#  Found model file method_s01-TrueVp.sgy
#  Vertical grid points in file:            81
#  Expecting:                               81
#  Profiles in file:                    123101
#  Expecting:                           123101
#  Maximum velocity (m/s):              6515.1
#  Minimum velocity (m/s):              1517.4
#  For high kernel:
#  Maximum allowable (m/s):            13187.0
#  High kernel OK below (Hz):              9.0
#  For low kernel:
#  Maximum allowable (m/s):             9900.0
#  Low kernel OK below (Hz):               4.9
#
#  There was nothing to plot
#
# Errors raised:
#  Unable to decode SEG-Y headers

# %% [markdown]
# # Run

# %% [markdown]
# Two nodes calculate 3000 time samples in exactly 1 hour.

# %%
syn.i.rsync('my_eph') 
syn.i.pbs.no[0].prep(q='debug')
syn.i.pbs.no[1].prep(select=2, q='pqmrwarn') # it took exactly an hour!!!
syn.i.rsync('my_eph')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-52-854856531b06> in <module>
#       1 syn.i.rsync('my_eph')
# ----> 2 syn.i.pbs.no[0].prep(q='debug')
#       3 syn.i.pbs.no[1].prep(select=2, q='pqmrwarn') # it took exactly an hour!!!
#       4 syn.i.rsync('my_eph')
#
# ~/software/fullwavepy/fullwavepy/project/files/generic.py in prep(self, *args, **kwargs)
#      54   """
#      55   def prep(self, *args, **kwargs):
# ---> 56     super().prep(*args, **kwargs)
#      57
#      58     cat = kw('cat', True, kwargs)
#
# /usr/local/lib/python3.5/dist-packages/autologging.py in autologging_traced_instancemethod_delegator(self_, *args, **keywords)
#    1039             return proxy(method, args, keywords)
#    1040         else:
# -> 1041             return method(*args, **keywords)
#    1042
#    1043     autologging_traced_instancemethod_delegator._tracing_proxy = proxy
#
# ~/software/fullwavepy/fullwavepy/ioapi/generic.py in prep(self, *args, **kwargs)
#      27
#      28     if dupl is None:
# ---> 29       self.create(*args, **kwargs)
#      30     else:
#      31       del_kw('dupl', kwargs)
#
# /usr/local/lib/python3.5/dist-packages/autologging.py in autologging_traced_instancemethod_delegator(self_, *args, **keywords)
#    1039             return proxy(method, args, keywords)
#    1040         else:
# -> 1041             return method(*args, **keywords)
#    1042
#    1043     autologging_traced_instancemethod_delegator._tracing_proxy = proxy
#
# ~/software/fullwavepy/fullwavepy/project/files/text/submit.py in create(self, **kwargs)
#      41     super().__init__(proj, path, suffix, exten, run_id, **kwargs)
#      42   def create(self, **kwargs):
# ---> 43     self._prevent_overwriting(**kwargs)
#      44     self._write_all(**kwargs)
#      45   def dupl(self, source, **kwargs):
#
# /usr/local/lib/python3.5/dist-packages/autologging.py in autologging_traced_instancemethod_delegator(self_, *args, **keywords)
#    1039             return proxy(method, args, keywords)
#    1040         else:
# -> 1041             return method(*args, **keywords)
#    1042
#    1043     autologging_traced_instancemethod_delegator._tracing_proxy = proxy
#
# ~/software/fullwavepy/fullwavepy/project/files/text/submit.py in _prevent_overwriting(self, **kwargs)
#     114       fname = f.no[self.run_id].fname
#     115       if exists(fname):
# --> 116         raise OSError("{} already exists!".format(fname))
#     117   # -----------------------------------------------------------------------------
#     118 @traced
#
# OSError: /home/kmc3817/rds_home/my_ephemeral/PROJECTS/ch08_Kolumbo_volcano/method_s01//inp/method_s01-JobInfo0.log already exists!

# %% [markdown]
# On the `cx1` PBS cluster, first **set environment** vars:

# %%
# dir=my_ephemeral/PROJECTS/ch08_Kolumbo_volcano; code=rev690; proj=method_syn01; q=pqmrwarn

# %% [markdown]
# and then **submit** the job(s):

# %%
# dir=$dir; code=$code; q=$q; projs=$(ls $dir | grep $proj);
# for proj in $projs; do echo $proj; fwi_qsub.sh $dir/$proj/ $proj $code $q; donea

# %% [markdown]
# ### Logs

# %%
no = 1
syn.o.o.no[no].cat()
# syn.o.je.no[no].cat()
# syn.o.jo.no[no].cat()
# Out:
# Content of  /home/kmc3817/rds_home/my_ephemeral/PROJECTS/ch08_Kolumbo_volcano/method_s01//out/method_s01-Out1.log :
# # mpiexec: No RDMA network found -- using sockets+shared memory (I_MPI_DEVICE=ssm)
# # mpiexec: full path to program is /rds/general/user/kmc3817/home/PhD/fullwave3D/rev690/bin/fullwave3D.exe
# # mpiexec: program arguments are: method_s01 -1 40
# # mpiexec: 2 ranks allocated via PBS select
# # mpiexec: 40 OpenMP threads / rank allocated by PBS select
# # mpiexec: Job has shared use of the allocated nodes. Disabling process-pinning
# # mpiexec: machinefile configured as:
# cx1-104-11-1.cx1.hpc.ic.ac.uk:1
# cx1-104-11-4.cx1.hpc.ic.ac.uk:1
# #
# # mpiexec: Checking all nodes are ONLINE:
# # mpiexec: All nodes appear ONLINE
# # mpiexec: launch started at Wed  3 Nov 14:37:35 GMT 2021
# # mpiexec: launching program...
# # /rds/general/user/kmc3817/home/PhD/fullwave3D/rev690/bin/fullwave3D.exe method_s01 -1 40
# (cx1-104-11-1.cx1.hpc.ic.ac.uk:0)
# (cx1-104-11-4.cx1.hpc.ic.ac.uk:1)
# ---=== Starting run (host: cx1-104-11-1.cx1.hpc.ic.ac.uk) on 2021/11/03, 14:37:35 ===---
# executable: fullwave3D.exe, version: unknown, release date: 2021-11-03
# === [14:37:35] scheduler_getprojargs: Project name (command-line argument): "method_s01"
# === [14:37:35] scheduler_getprojargs: Checkpoint number (command-line argument): -1
# === [14:37:35] setup_probtype: Equation: "acoustic", Anisotropy: "none", Domain: "time", Kernel: "low"
# +++ [14:37:35] ReadParms: WARNING, unknown keyword in Runfile: "ibfs"
# +++ [14:37:35] ReadParms: WARNING, unknown keyword in Runfile: "multisurf"
# +++ [14:37:35] ReadParms: WARNING, unknown keyword in Runfile: "nosprdfctrs"
# +++ [14:37:35] ReadParms: WARNING, unknown keyword in Runfile: "seaLevel"
# +++ [14:37:35] ReadParms: WARNING, unknown keyword in Runfile: "maxGhostIter"
# +++ [14:37:35] ReadParms: WARNING, unknown keyword in Runfile: "vacuum"
# +++ [14:37:35] ReadParms: WARNING, unknown keyword in Runfile: "accuracy"
# +++ [14:37:35] ReadParms: WARNING, unknown keyword in Runfile: "minGhostFS"
# +++ [14:37:35] ReadParms: WARNING, unknown keyword in Runfile: "minFictFS"
# +++ [14:37:35] ReadParms: WARNING, unknown keyword in Runfile: "interpMode"
# +++ [14:37:35] ReadParms: WARNING, unknown keyword in Runfile: "iprop"
#     [14:37:35] read_runfile: number of iteration blocks in "method_s01-Runfile.key": 1
#     [14:37:35] read_runfile: total time given in "method_s01-Runfile.key": 7.500000 seconds
#     [14:37:35] scheduler_readinput: Grid dimensions (Length x Width x Depth): 441x461x133 cells
#     [14:37:36] read_modelprop: Got Vp model from "method_s01-TrueVp.sgy"
#     [14:37:37] scheduler_readinput: Initial min/max Vp (m/s): 1517.41, 6515.07
#     [14:37:37] scheduler_readinput: Initial min/max Qp: 0.00, 0.00
#     [14:37:37] scheduler_readinput: Max. reliable pressure wave propagation frequency on this grid is about 6.07Hz
#     [14:37:37] getall: Time-step: 2.5000E-03, maximum trace-length: 7.5000E+00
#     [14:37:37] getall: number of composite shots found in "method_s01-Signature.sgy": 16
#     [14:37:37] GetShotPointSourceWaveletsInfo: number of composite shots found in "method_s01-Template.sgy": 16
# ---=== Scheduler initialisation complete. Ready for slaves on 2021/11/03, 14:37:37 ===---
#     [14:37:37] scheduler_run: tasks left for synthetic problem: 16 (out of 16)
#     [14:37:39] (Slave1;CSRef4124;SrcID4) slave_timesolve: starting 3000 time-steps with 40 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     
(Slave1;CSRef4178;SrcID10) fbtimesol: writing wavefield data to "fw-002900-csref04178-iter00001-taskid00014.vtr"
#     [15:30:13] (Slave1;CSRef4178;SrcID10) fbtimesol: writing wavefield data to "fw-003000-csref04178-iter00001-taskid00014.vtr"
#     [15:30:14] scheduler_slavesynd: got observed data (no=1505) from slave id 1 (srcid=10,blkid=1,csrgid=10,obscnt=1)
# === [15:30:14] scheduler_writeobserved: appending synthetic data for 1505 receivers in composite shot 10 to synthetic traces file
#     [15:30:16] (Slave1;CSRef4112;SrcID3) slave_timesolve: starting 3000 time-steps with 40 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [15:30:17] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-000100-csref04112-iter00001-taskid00015.vtr"
#     [15:30:18] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-000200-csref04112-iter00001-taskid00015.vtr"
#     [15:30:20] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-000300-csref04112-iter00001-taskid00015.vtr"
#     [15:30:22] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-000400-csref04112-iter00001-taskid00015.vtr"
#     [15:30:25] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-000500-csref04112-iter00001-taskid00015.vtr"
#     [15:30:30] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-000600-csref04112-iter00001-taskid00015.vtr"
#     [15:30:34] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-000700-csref04112-iter00001-taskid00015.vtr"
#     [15:30:40] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-000800-csref04112-iter00001-taskid00015.vtr"
#     [15:30:46] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-000900-csref04112-iter00001-taskid00015.vtr"
#     [15:30:53] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-001000-csref04112-iter00001-taskid00015.vtr"
#     [15:31:01] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-001100-csref04112-iter00001-taskid00015.vtr"
#     [15:31:10] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-001200-csref04112-iter00001-taskid00015.vtr"
#     [15:31:20] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-001300-csref04112-iter00001-taskid00015.vtr"
#     [15:31:30] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-001400-csref04112-iter00001-taskid00015.vtr"
#     [15:31:39] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-001500-csref04112-iter00001-taskid00015.vtr"
#     [15:31:49] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-001600-csref04112-iter00001-taskid00015.vtr"
#     [15:31:59] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-001700-csref04112-iter00001-taskid00015.vtr"
#     [15:32:09] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-001800-csref04112-iter00001-taskid00015.vtr"
#     [15:32:19] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-001900-csref04112-iter00001-taskid00015.vtr"
#     [15:32:28] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-002000-csref04112-iter00001-taskid00015.vtr"
#     [15:32:38] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-002100-csref04112-iter00001-taskid00015.vtr"
#     [15:32:48] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-002200-csref04112-iter00001-taskid00015.vtr"
#     [15:32:58] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-002300-csref04112-iter00001-taskid00015.vtr"
#     [15:33:07] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-002400-csref04112-iter00001-taskid00015.vtr"
#     [15:33:17] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-002500-csref04112-iter00001-taskid00015.vtr"
#     [15:33:27] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-002600-csref04112-iter00001-taskid00015.vtr"
#     [15:33:35] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-002700-csref04112-iter00001-taskid00015.vtr"
#     [15:33:41] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-002800-csref04112-iter00001-taskid00015.vtr"
#     [15:33:45] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-002900-csref04112-iter00001-taskid00015.vtr"
#     [15:33:48] (Slave1;CSRef4112;SrcID3) fbtimesol: writing wavefield data to "fw-003000-csref04112-iter00001-taskid00015.vtr"
#     [15:33:50] scheduler_slavesynd: got observed data (no=1505) from slave id 1 (srcid=3,blkid=1,csrgid=3,obscnt=1)
# === [15:33:50] scheduler_writeobserved: appending synthetic data for 1505 receivers in composite shot 3 to synthetic traces file
#     [15:33:51] (Slave1;CSRef4105;SrcID11) slave_timesolve: starting 3000 time-steps with 40 threads (bnds:40,40,40,40,0,40 weipar:0.000,0.000)
#     [15:33:51] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-000100-csref04105-iter00001-taskid00016.vtr"
#     [15:33:53] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-000200-csref04105-iter00001-taskid00016.vtr"
#     [15:33:55] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-000300-csref04105-iter00001-taskid00016.vtr"
#     [15:33:57] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-000400-csref04105-iter00001-taskid00016.vtr"
#     [15:34:00] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-000500-csref04105-iter00001-taskid00016.vtr"
#     [15:34:04] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-000600-csref04105-iter00001-taskid00016.vtr"
#     [15:34:09] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-000700-csref04105-iter00001-taskid00016.vtr"
#     [15:34:14] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-000800-csref04105-iter00001-taskid00016.vtr"
#     [15:34:20] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-000900-csref04105-iter00001-taskid00016.vtr"
#     [15:34:28] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-001000-csref04105-iter00001-taskid00016.vtr"
#     [15:34:36] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-001100-csref04105-iter00001-taskid00016.vtr"
#     [15:34:46] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-001200-csref04105-iter00001-taskid00016.vtr"
#     [15:34:55] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-001300-csref04105-iter00001-taskid00016.vtr"
#     [15:35:05] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-001400-csref04105-iter00001-taskid00016.vtr"
#     [15:35:15] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-001500-csref04105-iter00001-taskid00016.vtr"
#     [15:35:25] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-001600-csref04105-iter00001-taskid00016.vtr"
#     [15:35:35] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-001700-csref04105-iter00001-taskid00016.vtr"
#     [15:35:45] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-001800-csref04105-iter00001-taskid00016.vtr"
#     [15:35:55] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-001900-csref04105-iter00001-taskid00016.vtr"
#     [15:36:05] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-002000-csref04105-iter00001-taskid00016.vtr"
#     [15:36:15] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-002100-csref04105-iter00001-taskid00016.vtr"
#     [15:36:25] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-002200-csref04105-iter00001-taskid00016.vtr"
#     [15:36:35] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-002300-csref04105-iter00001-taskid00016.vtr"
#     [15:36:44] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-002400-csref04105-iter00001-taskid00016.vtr"
#     [15:36:54] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-002500-csref04105-iter00001-taskid00016.vtr"
#     [15:37:04] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-002600-csref04105-iter00001-taskid00016.vtr"
#     [15:37:12] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-002700-csref04105-iter00001-taskid00016.vtr"
#     [15:37:18] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-002800-csref04105-iter00001-taskid00016.vtr"
#     [15:37:22] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-002900-csref04105-iter00001-taskid00016.vtr"
#     [15:37:25] (Slave1;CSRef4105;SrcID11) fbtimesol: writing wavefield data to "fw-003000-csref04105-iter00001-taskid00016.vtr"
#     [15:37:27] scheduler_slavesynd: got observed data (no=1505) from slave id 1 (srcid=11,blkid=1,csrgid=11,obscnt=1)
# === [15:37:27] scheduler_writeobserved: appending synthetic data for 1505 receivers in composite shot 11 to synthetic traces file
#     [15:37:29] scheduler_run: no need to wait for final data to be written
# ---=== Ending run on 2021/11/03, 15:37:30 ===---
# # mpiexec: finished at Wed  3 Nov 15:37:30 GMT 2021

# %% [markdown]
# # Out

# %% [markdown]
# ### Data

# %% [markdown]
# #### Fig.
# Synthetics.

# %%
figure(15,5)
syn.out.syn.plot(win=dict(tracf=[4104]), norm='max')

# %% [markdown]
# #### Alg.
# Copy the synthetics from `ephemeral` to local permanent storage.

# %%
# !cp {syn.o.syn.fname} ./method_s01/out/

# %% [markdown]
# #### Tab.
# Synthetics header.

# %%
syn.o.syn.surange()
# Out:
# 3200+0 records in
# 6+1 records out
# 3200 bytes (3.2 kB, 3.1 KiB) copied, 0.00847586 s, 378 kB/s
#
# 24080 traces:
# tracl    3555 13370 (3555 - 13370)
# tracr    2 1506 (2 - 1506)
# fldr     17567 42821 (17567 - 42821)
# tracf    4104 4178 (4104 - 4176)
# ep       5 38 (5 - 38)
# cdpt     0 1 (0 - 1)
# trid     1
# offset   10 21208 (10473 - 19597)
# gelev    196 456 (417 - 410)
# selev    -12
# sdepth   12
# swdep    45 503 (395 - 393)
# gwdep    196 456 (417 - 410)
# scalel   1
# scalco   1
# sx       8051 24996 (8201 - 8128)
# sy       -2126 13847 (13742 - 13727)
# gx       8863 24030 (18674 - 21101)
# gy       -1040 13806 (13806 - -960)
# counit   1
# tstat    17
# delrt    0 5 (0 - 4)
# ns       3000
# dt       2500
# gain     0 1 (1 - 0)
# igc      0 16 (16 - 0)
# year     2015
# day      331 340 (331 - 340)
# hour     0 23 (3 - 15)
# minute   0 59 (4 - 18)
# sec      0 59 (55 - 43)
# timbas   0 1000 (435 - 737)
#
# Shot coordinate limits:
# 	North(23852,13847) South(10038,-2126) East(24996,656) West(8051,11996)
#
# Receiver coordinate limits:
# 	North(18674,13806) South(9821,-1040) East(24030,7042) West(8863,4208)
#
# Midpoint coordinate limits:
# 	North(21263,13826.5) South(9929.5,-1583) East(24513,3849) West(8457,8102)

# %% [markdown]
# ### Wavefield

# %%
tvp = Arr3d(s01.i.tvp.read(), extent=s01.i.tvp.extent)

# %%
figure(15,5)
i = 0
tvp.slice(13.25e3, axis=0, unit='m')
tvp.slices.list[0].plot()

# %%
figure(15,5)
tvp.slice(13.25e3, axis=0, unit='m')
tvp.slices.list[0].plot()

# %%
tvp.slices.list[0].axes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-72674d07899c> in <module>
# ----> 1 tvp.slices.list[0].axes
#
# AttributeError: 'Arr3dSliceX' object has no attribute 'axes'

# %%
from arrau.a3d import Arr2d, Arr3d
class Vp:
    pass
class Mod:
    def __init__(self, param='vp', unit='m/s', srcs=None, recs=None,
                 arr=None, bt=None, fs=None, fw=None, bw=None):
        self.param = param
        self.unit = 'm/s'
        self._init_param(param)
        self.arr = arr
        self.bt = bt
        self.fw = fw
        self.srcs = srcs
        self.recs = recs
        self._set_objs()
    def plot(self, *args, **kwargs):
        kwargs['cmap'] = kwargs.get('cmap', 'twilight')
        self.arr.plot(*args, **kwargs)
    def read(self, file_object, attr='arr', **kwargs):
        setattr(self, attr, file_object.read(**kwargs))
    def set(self, arr, attr='arr'):
        setattr(self, attr, arr)
        self._set_objs()
    def slice(self, *args, **kwargs):
        for obj in self.objs:
            if obj is not None:
                obj.slice(*args, **kwargs)
    def plot(self, *args, **kwargs):
        self.slice(*args, **kwargs)
        i = 0
        kwargs['cmap'] = kwargs.get('cmap', 'twilight')
        kwargs['label'] = kwargs.get('label', '%s, %s' % (self.param, self.unit))
        self.arr.slices.list[i].plot(**kwargs)
        self.arr.slices.list[i].plot_slice_lines()
        for obj in self.objs[1:]: # skip arr
            if obj is not None:
                obj.slices.list[i].plot(**kwargs)        
    def _init_param(self, param):
        if param == 'vp':
            self.param = Vp()
        else:
            raise ValueError()
    def _set_objs(self):
        # the order matters for plots
        self.objs = [self.arr]# , self.fs, self.fw, self.bw, srcs, recs]
    def _slice3(self):
        pass
m = Mod()
m.set(tvp)
# m.slice(13.25e3, axis=0, unit='m')
# m.arr.slices.list[0].value
figure(15,5)
m.plot(13.25e3, axis=0, unit='m', label='vp, m/s')

# %% [markdown]
# #### Alg.
# Test `fullwavepy.seismic.fields`

# %%
# !python3 -m unittest fullwavepy.seismic.test.test_wavefields -v

# %% [markdown]
# # ...
